# %% [markdown]
# # SCS 3546: Deep Learning
# > **Assignment 3: Contextualized Word Embeddings**

# %% [markdown]
# ### Your name & student number:
#
# <pre> Student Name: Fernando Espinosa </pre>
#
# <pre> Student Number: X566420 </pre>

# %% [markdown]
# ## **Assignment Description**
# ***
#
# Search Engines are a standard tool for finding relevant content. The calculation of similarity between textual information is an important factor for better search results.
#
# ### **Objectives**
#
# **Your goal in this assignment is to calculate the textual similarity between queries and the provided sample documents, using a variety of NLP approaches.**
#
# In achieving the above goal, you will also:
# - Demonstrate how to preprocess text and embed textual data.
# - Compare the results of textual similarity scoring between traditional and deep-learning based NLP methods.
#
# ### **Data and Queries**
#
# You will use the document repository provided by `sample_repository.json`, which you can download from the following link, or from the assignment description in Quercus: https://q.utoronto.ca/courses/286389/files/21993451/download?download_frd=1
#
# The queries you will run against these sample documents are the following:
#
# - Query 1: “fruits”
# - Query 2: “vegetables”
# - Query 3: “healthy foods in Canada”
#
# ### **Techniques to Demonstrate**
#
# The techniques you will use to compute the similarity scores are:
# - 1. TF-IDF.
# - 2. Semantic similarity using GloVe word vectors.
# - 3. Semantic similarity using a BERT-based model.
#
#
# ### **Feel Free to Choose Your Own Approach**
#
# How you go about demonstrating each of the above techniques is up to you. You are not expected to use any particular library. The code below is just meant to provide you with some guidance to get started. You **do**, however, need to demonstrate obtaining similarity scores **with all 3 techniques above**, but how you go about doing this is totally up to you. The evaluation will be based on your ability obtain results using all three techniques, plus your discussion/comparison of any differences you observe.

# %% [markdown]
# ## **Grade Allocation**
# ***
# 15 points total
#
# - Experiment 1 (TD-IDF), implementation: 2 marks
# - Experiment 2 (GloVe), implementation: 3 marks
# - Experiment 3 (BERT), implementation: 3 marks
# - Comparison and Discussion: 3 marks
#   - Compare all three techniques and interpret your findings. Do your best to explain the differences you observe in terms of concepts learned in class (not just the _what_, but also the _how_ and _why_ one technique produces different results from another).
# - Text Pre-Processing: 2 marks
#  - Cleaning and standardization (e.g. lemmatization, stemming) in Experiment 1
#  - Basic text cleaning (e.g. removal of special characters or tags) in Experiments 2 and 3.
# - Clarity: 2 marks
#  - The marks for clarity are awarded for code documentation, clean code (e.g. avoiding repetition by building re-usable functions)  and how well you explained/supported your answers, including the use of visualizations.

# %% [markdown]
# # Setup and Data Import
# ***
# You can use the code snippets below to help you load and extract the document repository.

# %%
# you can either drop the file manually into your Colab drive, or otherwise
# use this widget to upload it

from google.colab import files
# uploaded = files.upload()

# %%
# this will unpack the json file contents into a list of titles and documents
import json

with open('sample_repository.json') as in_file:
    repo_data = json.load(in_file)

titles = [item[0] for item in repo_data['data']]
documents = [item[1] for item in repo_data['data']]

# %%
# let's take a look at some of these documents and titles;
# here we print the five last entries
for id in range(-5, 0, 1):
  print(f"Document title: {titles[id]}")
  print(f"Document contents: {documents[id]}")
  print("\n") # adds newline
# Out:
# Document title: botany
# Document contents: Botany, also called plant science(s), plant biology or phytology, is the science of plant life and a branch of biology. A botanist, plant scientist or phytologist is a scientist who specialises in this field.
#
#
# Document title: Ford Bronco
# Document contents: The Ford Bronco is a model line of sport utility vehicles manufactured and marketed by Ford. ... The first SUV model developed by the company, five generations of the Bronco were sold from the 1966 to 1996 model years. A sixth generation of the model line is sold from the 2021 model year. the Ford Bronco will be available in Canada, with first deliveries beginning in spring of 2021. The Bronco will come in six versions in Canada: Base, Big Bend, Black Diamond, Outer Banks, Wildtrak and Badlands.
#
#
# Document title: List of fruit dishes
# Document contents: Fruit dishes are those that use fruit as a primary ingredient. Condiments prepared with fruit as a primary ingredient are also included in this list.
#
#
# Document title: Neuro linguistic programming
# Document contents: Neuro linguistic programming (NLP) is a pseudoscientific approach to communication, personal development, and psychotherapy created by Richard Bandler and John Grinder in California, United States, in the 1970s.
#
#
# Document title: fruit serving bowl
# Document contents: A fruit serving bowl is a round dish or container typically used to prepare and serve food. The interior of a bowl is characteristically shaped like a spherical cap, with the edges and the bottom forming a seamless curve. This makes bowls especially suited for holding liquids and loose food, as the contents of the bowl are naturally concentrated in its center by the force of gravity.

# %% [markdown]
# # Experiment 1: TF-IDF
# ***
#
# **T**erm **F**requency - **I**nverse **D**ocument **F**requency (TF-IDF) is a traditional NLP technique to look at words that appear in both pieces of text, and score them based on how often they appear. For this experiment, you are free to use the TF-IDF implementation provided by scikit-learn.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

nltk.download('punkt')
stop_words = set(stopwords.words('english'))

print(f'stop_words: {type(stop_words)}')

# > need to keep the list to avoid error in TfidfVectorizer() contructor:
#   InvalidParameterError: The 'stop_words' parameter of TfidfVectorizer must be
#   a str among {'english'}, an instance of 'list' or None ...

stop_words_list = list(stop_words)
print(f'stop_words_list: {type(stop_words_list)}')
# Out:
# stop_words: <class 'set'>
# stop_words_list: <class 'list'>
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
vectorizer = TfidfVectorizer(stop_words=stop_words_list)

# > fit the TF-IDF vectorizer to the document corpus and transform the documents
#   into TF-IDF vectors
document_vectors = vectorizer.fit_transform(documents)

# %%
# Calculate the word frequency, and a measure of similarity of the search terms with each document.
# Do not apply any text pre-processing (i.e. cleanup) yet.

# > calculate word frequencies (TF-IDF values)
frequencies = document_vectors.toarray()
# > get feature names to see which words are retained
terms = vectorizer.get_feature_names_out()

# > print term frequencies for each document
print("Word Frequencies (TF-IDF values):")
for i, doc in enumerate(documents):
    print(f"document #{i}: {doc}")
    for j, term in enumerate(terms):
        if frequencies[i, j] > 0:  # only show terms with non-zero TF-IDF
            print(f"  {term}: {frequencies[i, j]:.4f}")
    print()
# Out:
# Word Frequencies (TF-IDF values):
# document #0: Fresh Pomegranate from Anushka Avni International Bhagwa is a premium Pomegranate variety from India. The Deep Red arils & the pleasing Red but rugged skin enhances the appearance whilst promoting shelf life of the fruit. Bhagwa is widely known for its soft seed, Dark red color and extremely delicious. Packaging: Net weight of box 2.5kg, 3.00kg, 3.5kg. Details: Minimum Weight 180gm, maximum weight 400gm Color of arils: Dark Cherry red. Taste: Sweet Fruit count / carton (3.50 kg net wt.) 9 Numbers packed per carton: 350-400gms
#   00kg: 0.1041
#   180gm: 0.1041
#   350: 0.1041
#   400gm: 0.1041
#   400gms: 0.1041
#   50: 0.0829
#   5kg: 0.1658
#   anushka: 0.0592
#   appearance: 0.1166
#   arils: 0.2083
#   avni: 0.0592
#   bhagwa: 0.2331
#   box: 0.1041
#   carton: 0.1770
#   cherry: 0.1166
#   color: 0.2331
#   count: 0.1041
#   dark: 0.2083
#   deep: 0.1166
#   delicious: 0.1166
#   details: 0.0885
#   enhances: 0.1166
#   extremely: 0.1166
#   fresh: 0.0741
#   fruit: 0.1658
#   india: 0.1041
#   international: 0.0592
#   kg: 0.0829
#   known: 0.1166
#   life: 0.0953
#   maximum: 0.1041
#   minimum: 0.1041
#   net: 0.2083
#   numbers: 0.1041
#   packaging: 0.0741
#   packed: 0.1041
#   per: 0.0741
#   pleasing: 0.1166
#   pomegranate: 0.2083
#   premium: 0.1166
#   promoting: 0.1166
#   red: 0.2963
#   rugged: 0.1166
#   seed: 0.1166
#   shelf: 0.1166
#   skin: 0.0885
#   soft: 0.1041
#   sweet: 0.0953
#   taste: 0.0885
#   variety: 0.1041
#   weight: 0.3124
#   whilst: 0.1166
#   widely: 0.1041
#   wt: 0.1041
#
# document #1: Fresh Pomegranate Arakta from Anushka Avni International This Pomegranate are bigger in size, sweet with soft seeds, bold red arils. It also possess glossy, attractive, dark red skin. Packaging: Net weight of box 2.5kg, 3.00kg, 3.5kg. Details: Minimum Weight 180gm, maximum weight 400gm Taste: Sweet Fruit count / carton (3.50 kg net wt.) 9 Numbers packed per carton: 350-400gms 10 Numbers packed per carton :290-320gms 12 Numbers packed per carton: 275-325gms 15 Numbers packed per carton: 225-275gms Load ability: 4400 cartons per container 20 pallets with 220 cartons per pallet Load ability: 5500 cartons per container Loading with No pallets Availability: January | February | March | April | July | August | September | October | Nov | Dec READ MORE
#   00kg: 0.0750
#   10: 0.0840
#   12: 0.0637
#   15: 0.0840
#   180gm: 0.0750
#   20: 0.0840
#   220: 0.0840
#   225: 0.0840
#   275: 0.0840
#   275gms: 0.0840
#   290: 0.0840
#   320gms: 0.0840
#   325gms: 0.0840
#   350: 0.0750
#   400gm: 0.0750
#   400gms: 0.0750
#   4400: 0.0840
#   50: 0.0597
#   5500: 0.0840
#   5kg: 0.1194
#   ability: 0.1126
#   also: 0.0597
#   anushka: 0.0426
#   april: 0.0687
#   arakta: 0.0840
#   arils: 0.0750
#   attractive: 0.0840
#   august: 0.0840
#   availability: 0.0637
#   avni: 0.0426
#   bigger: 0.0840
#   bold: 0.0840
#   box: 0.0750
#   carton: 0.3187
#   cartons: 0.1912
#   container: 0.1067
#   count: 0.0750
#   dark: 0.0750
#   dec: 0.0840
#   details: 0.0637
#   february: 0.0687
#   fresh: 0.0534
#   fruit: 0.0597
#   glossy: 0.0840
#   international: 0.0426
#   january: 0.0687
#   july: 0.0840
#   kg: 0.0597
#   load: 0.1126
#   loading: 0.0840
#   march: 0.0687
#   maximum: 0.0750
#   minimum: 0.0750
#   net: 0.1501
#   nov: 0.0840
#   numbers: 0.3001
#   october: 0.0840
#   packaging: 0.0534
#   packed: 0.3001
#   pallet: 0.0840
#   pallets: 0.1680
#   per: 0.3736
#   pomegranate: 0.1501
#   possess: 0.0840
#   read: 0.0687
#   red: 0.1067
#   seeds: 0.0840
#   september: 0.0840
#   size: 0.0637
#   skin: 0.0637
#   soft: 0.0750
#   sweet: 0.1373
#   taste: 0.0637
#   weight: 0.2251
#   wt: 0.0750
#
# document #2: About Us Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying… Read More..
#   aai: 0.1562
#   agro: 0.1562
#   anushka: 0.1183
#   assortment: 0.1562
#   available: 0.1480
#   avni: 0.1183
#   best: 0.1905
#   buyers: 0.1562
#   come: 0.1408
#   exporter: 0.1562
#   feel: 0.1562
#   follow: 0.1768
#   huge: 0.1562
#   international: 0.1183
#   market: 0.1562
#   offer: 0.1562
#   one: 0.1285
#   pleasure: 0.1562
#   practices: 0.1905
#   presenting: 0.1562
#   products: 0.1562
#   proud: 0.1562
#   quality: 0.1480
#   read: 0.1905
#   recognizing: 0.1562
#   renowned: 0.1562
#   standard: 0.1562
#   suppliers: 0.1344
#   supplying: 0.1905
#   takes: 0.1562
#   us: 0.4687
#   wide: 0.1562
#   world: 0.1562
#
# document #3: About Us Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying… Read More..
#   aai: 0.1562
#   agro: 0.1562
#   anushka: 0.1183
#   assortment: 0.1562
#   available: 0.1480
#   avni: 0.1183
#   best: 0.1905
#   buyers: 0.1562
#   come: 0.1408
#   exporter: 0.1562
#   feel: 0.1562
#   follow: 0.1768
#   huge: 0.1562
#   international: 0.1183
#   market: 0.1562
#   offer: 0.1562
#   one: 0.1285
#   pleasure: 0.1562
#   practices: 0.1905
#   presenting: 0.1562
#   products: 0.1562
#   proud: 0.1562
#   quality: 0.1480
#   read: 0.1905
#   recognizing: 0.1562
#   renowned: 0.1562
#   standard: 0.1562
#   suppliers: 0.1344
#   supplying: 0.1905
#   takes: 0.1562
#   us: 0.4687
#   wide: 0.1562
#   world: 0.1562
#
# document #4: White Onions from Anushka Avni International Fresh White Onion, which is widely acclaimed for its health benefits and is used for different cuisines. We are a major exporters and suppliers of all kinds of fresh onions like red onions, pink onions and white onions. Sizes: 30-45 mm 45-55 mm 50 mm and above 55-70 mm 60 and above Packaging: 2.5kg, 3kg, 5kg, 9kg, 10kg, 15kg, 17kg, 18kg, 20kg, 25kg, 30kg Red Mesh Bag or Jute Bag Load ability: 12.5 MT per 20ft container ODO 28 MT per 40ft Refer container.
#   10kg: 0.0931
#   12: 0.0864
#   15kg: 0.0931
#   17kg: 0.0931
#   18kg: 0.0931
#   20ft: 0.0931
#   20kg: 0.0931
#   25kg: 0.0931
#   28: 0.0931
#   30: 0.0931
#   30kg: 0.0931
#   3kg: 0.0931
#   40ft: 0.0931
#   45: 0.1862
#   50: 0.0810
#   55: 0.1862
#   5kg: 0.1619
#   60: 0.0931
#   70: 0.0931
#   9kg: 0.0931
#   ability: 0.0763
#   acclaimed: 0.1138
#   anushka: 0.0578
#   avni: 0.0578
#   bag: 0.1862
#   benefits: 0.1138
#   container: 0.1447
#   cuisines: 0.1138
#   different: 0.1138
#   exporters: 0.0931
#   fresh: 0.1447
#   health: 0.1017
#   international: 0.0578
#   jute: 0.0931
#   kinds: 0.0931
#   like: 0.0810
#   load: 0.0763
#   major: 0.0864
#   mesh: 0.0931
#   mm: 0.3724
#   mt: 0.1862
#   odo: 0.0931
#   onion: 0.0931
#   onions: 0.4321
#   packaging: 0.0723
#   per: 0.1447
#   pink: 0.1017
#   red: 0.1447
#   refer: 0.0931
#   sizes: 0.0931
#   suppliers: 0.0657
#   used: 0.0810
#   white: 0.2793
#   widely: 0.1017
#
# document #5: Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market.
#   aai: 0.1865
#   agro: 0.1865
#   anushka: 0.1412
#   assortment: 0.1865
#   available: 0.1767
#   avni: 0.1412
#   buyers: 0.1865
#   come: 0.1681
#   exporter: 0.1865
#   feel: 0.1865
#   huge: 0.1865
#   international: 0.1412
#   market: 0.1865
#   offer: 0.1865
#   one: 0.1535
#   pleasure: 0.1865
#   presenting: 0.1865
#   products: 0.1865
#   proud: 0.1865
#   quality: 0.1767
#   recognizing: 0.1865
#   renowned: 0.1865
#   standard: 0.1865
#   suppliers: 0.1604
#   takes: 0.1865
#   us: 0.3730
#   wide: 0.1865
#   world: 0.1865
#
# document #6: To a botanist, a fruit is an entity that develops from the fertilized ovary of a flower. This means that tomatoes, squash, pumpkins, cucumbers, peppers, eggplants, corn kernels, and bean and pea pods are all fruits; so are apples, pears, peaches, apricots, melons and mangos
#   apples: 0.2004
#   apricots: 0.2004
#   bean: 0.2004
#   botanist: 0.1790
#   corn: 0.2004
#   cucumbers: 0.2004
#   develops: 0.2004
#   eggplants: 0.2004
#   entity: 0.2004
#   fertilized: 0.2004
#   flower: 0.2004
#   fruit: 0.1425
#   fruits: 0.1790
#   kernels: 0.2004
#   mangos: 0.2004
#   means: 0.2004
#   melons: 0.2004
#   ovary: 0.2004
#   pea: 0.2004
#   peaches: 0.2004
#   pears: 0.2004
#   peppers: 0.2004
#   pods: 0.2004
#   pumpkins: 0.2004
#   squash: 0.2004
#   tomatoes: 0.1790
#
# document #7: Nutrition is the biochemical and physiological process by which an organism uses intake to support its life. It includes ingestion, absorption, assimilation, biosynthesis, catabolism and excretion. The science that studies the physiological process of nutrition is called nutritional science (also nutrition science).
#   absorption: 0.1679
#   also: 0.1194
#   assimilation: 0.1679
#   biochemical: 0.1679
#   biosynthesis: 0.1679
#   called: 0.1275
#   catabolism: 0.1679
#   excretion: 0.1679
#   includes: 0.1679
#   ingestion: 0.1679
#   intake: 0.1679
#   life: 0.1373
#   nutrition: 0.4120
#   nutritional: 0.1679
#   organism: 0.1373
#   physiological: 0.3359
#   process: 0.3359
#   science: 0.4120
#   studies: 0.1679
#   support: 0.1679
#   uses: 0.1679
#
# document #8: Nutrients are substances used by an organism to survive, grow, and reproduce. The seven major classes of relevant nutrients for animals (including humans) are carbohydrates, dietary fiber, fats, proteins, minerals, vitamins, and water. Nutrients can be grouped as either macronutrients (carbohydrates, dietary fiber, fats, proteins, and water needed in gram quantities) or micronutrients (vitamins and minerals needed in milligram or microgram quantities).
#   animals: 0.1219
#   carbohydrates: 0.2437
#   classes: 0.1219
#   dietary: 0.2437
#   either: 0.1219
#   fats: 0.2437
#   fiber: 0.2437
#   gram: 0.1219
#   grouped: 0.1219
#   grow: 0.1219
#   humans: 0.1089
#   including: 0.1089
#   macronutrients: 0.1219
#   major: 0.0925
#   microgram: 0.1219
#   micronutrients: 0.1219
#   milligram: 0.1219
#   minerals: 0.2437
#   needed: 0.2437
#   nutrients: 0.3656
#   organism: 0.0996
#   proteins: 0.2437
#   quantities: 0.2437
#   relevant: 0.1219
#   reproduce: 0.1219
#   seven: 0.1219
#   substances: 0.1219
#   survive: 0.1219
#   used: 0.0867
#   vitamins: 0.2437
#   water: 0.2437
#
# document #9: In nutrition, the diet of an organism is the sum of foods it eats, which is largely determined by the availability and palatability of foods.
#   availability: 0.2299
#   determined: 0.3028
#   diet: 0.2705
#   eats: 0.3028
#   foods: 0.5411
#   largely: 0.3028
#   nutrition: 0.2476
#   organism: 0.2476
#   palatability: 0.3028
#   sum: 0.3028
#
# document #10: Canada's Food Guide is a nutrition guide produced by Health Canada to promote Healthy behaviours and habits, and lifestyles in Canada - this is to increase the number of healthy people in Canada. In 2007, it was reported to be the second most requested Canadian government publication, behind the Income Tax Forms. The Health Canada website states: Food guides are basic education tools that are designed to help people follow a healthy diet. The Guide recommends eating a variety of healthy foods each day including plenty of vegetables and fruits, protein foods, and whole grain foods. It recommends choosing protein foods that come from plants more often. It also recommends limiting highly processed foods.
#   2007: 0.0895
#   also: 0.0636
#   basic: 0.0895
#   behaviours: 0.0895
#   behind: 0.0895
#   canada: 0.3397
#   canadian: 0.0800
#   choosing: 0.0895
#   come: 0.0541
#   day: 0.0800
#   designed: 0.0895
#   diet: 0.0800
#   eating: 0.0895
#   education: 0.0895
#   follow: 0.0679
#   food: 0.1599
#   foods: 0.3998
#   forms: 0.0895
#   fruits: 0.0800
#   government: 0.0895
#   grain: 0.0895
#   guide: 0.2685
#   guides: 0.0895
#   habits: 0.0895
#   health: 0.1599
#   healthy: 0.3580
#   help: 0.0895
#   highly: 0.0895
#   including: 0.0800
#   income: 0.0895
#   increase: 0.0895
#   lifestyles: 0.0895
#   limiting: 0.0895
#   number: 0.0895
#   nutrition: 0.0732
#   often: 0.0800
#   people: 0.1790
#   plants: 0.0800
#   plenty: 0.0895
#   processed: 0.0895
#   produced: 0.0895
#   promote: 0.0895
#   protein: 0.1790
#   publication: 0.0895
#   recommends: 0.2685
#   reported: 0.0895
#   requested: 0.0895
#   second: 0.0895
#   states: 0.0800
#   tax: 0.0895
#   tools: 0.0800
#   variety: 0.0800
#   vegetables: 0.0895
#   website: 0.0895
#   whole: 0.0895
#
# document #11: UK, Nether Land, Russia, Canada, HongKong, Malaysia, Singapore, Oman, UAE, Qatar, Bahrain, Saudi Arabia, Mauritius, Maldives, Sri Lanka, Bangladesh
#   arabia: 0.2346
#   bahrain: 0.2346
#   bangladesh: 0.2346
#   canada: 0.1781
#   hongkong: 0.2346
#   land: 0.2346
#   lanka: 0.2346
#   malaysia: 0.2096
#   maldives: 0.2346
#   mauritius: 0.2346
#   nether: 0.2346
#   oman: 0.2346
#   qatar: 0.2346
#   russia: 0.2346
#   saudi: 0.2346
#   singapore: 0.2096
#   sri: 0.2346
#   uae: 0.2346
#   uk: 0.2346
#
# document #12: Canadian Industry Statistics (CIS) analyses industry data on many economic indicators in Canada
#   analyses: 0.2866
#   canada: 0.2176
#   canadian: 0.2561
#   cis: 0.2866
#   data: 0.2561
#   economic: 0.2866
#   indicators: 0.2866
#   industry: 0.5732
#   many: 0.2866
#   statistics: 0.2866
#
# document #13: Red Onions from Anushka Avni International Red onions, sometimes called purple onions, are cultivars of the onion with purplish red skin and white flesh tinged with red. We are a major Indian exporters and suppliers of all kinds of fresh onions like red onions and white onions. Sizes: 30-45 mm 45-55 mm 50 mm and above 55-70 mm 60 and above Packaging: 2.5kg, 3kg, 5kg, 9kg, 10kg, 15kg, 17kg, 18kg, 20kg, 25kg, 30kg Red Mesh Bag or Jute Bag Load ability: 12.5 MT per 20ft container ODO 28 MT per 40ft Refer container.
#   10kg: 0.0853
#   12: 0.0792
#   15kg: 0.0853
#   17kg: 0.0853
#   18kg: 0.0853
#   20ft: 0.0853
#   20kg: 0.0853
#   25kg: 0.0853
#   28: 0.0853
#   30: 0.0853
#   30kg: 0.0853
#   3kg: 0.0853
#   40ft: 0.0853
#   45: 0.1706
#   50: 0.0742
#   55: 0.1706
#   5kg: 0.1484
#   60: 0.0853
#   70: 0.0853
#   9kg: 0.0853
#   ability: 0.0700
#   anushka: 0.0530
#   avni: 0.0530
#   bag: 0.1706
#   called: 0.0792
#   container: 0.1326
#   cultivars: 0.0932
#   exporters: 0.0853
#   flesh: 0.0932
#   fresh: 0.0663
#   indian: 0.0932
#   international: 0.0530
#   jute: 0.0853
#   kinds: 0.0853
#   like: 0.0742
#   load: 0.0700
#   major: 0.0792
#   mesh: 0.0853
#   mm: 0.3412
#   mt: 0.1706
#   odo: 0.0853
#   onion: 0.0853
#   onions: 0.4751
#   packaging: 0.0663
#   per: 0.1326
#   purple: 0.0932
#   purplish: 0.1043
#   red: 0.3977
#   refer: 0.0853
#   sizes: 0.0853
#   skin: 0.0792
#   sometimes: 0.0932
#   suppliers: 0.0602
#   tinged: 0.0932
#   white: 0.1706
#
# document #14: Berry Size: 18mm and above Packaging Packing Size: 4.5 kg loose in carry bags 8.2 kg loose in carry bags 5 kg carton punnets10 x 500 gms Load ability: 5 kg – 2400 cartons per container 4.5 kilo – 3400 cartons per container 8.2 kilo – 2040 cartons per container Availability: December | January | February | March | April
#   18mm: 0.1290
#   2040: 0.1290
#   2400: 0.1290
#   3400: 0.1290
#   500: 0.1290
#   ability: 0.0968
#   april: 0.1181
#   availability: 0.1096
#   bags: 0.2580
#   berry: 0.1181
#   carry: 0.2580
#   carton: 0.1096
#   cartons: 0.3288
#   container: 0.2753
#   december: 0.1290
#   february: 0.1181
#   gms: 0.1290
#   january: 0.1181
#   kg: 0.4108
#   kilo: 0.2580
#   load: 0.0968
#   loose: 0.2362
#   march: 0.1181
#   packaging: 0.0918
#   packing: 0.1181
#   per: 0.2753
#   punnets10: 0.1290
#   size: 0.2192
#
# document #15: Pink Onions from Anushka Avni International Pink onions, sometimes called summer onions, are cultivars of the onion with pink skin and white flesh tinged with red. We are a major Indian exporters and suppliers of all kinds of fresh onions like red onions, pink onions and white onions. Sizes: 30-45 mm 45-55 mm 50 mm and above 55-70 mm 60 and above Packaging: 2.5kg, 3kg, 5kg, 9kg, 10kg, 15kg, 17kg, 18kg, 20kg, 25kg, 30kg Red Mesh Bag or Jute Bag Load ability: 12.5 MT per 20ft container ODO 28 MT per 40ft Refer container.
#   10kg: 0.0816
#   12: 0.0757
#   15kg: 0.0816
#   17kg: 0.0816
#   18kg: 0.0816
#   20ft: 0.0816
#   20kg: 0.0816
#   25kg: 0.0816
#   28: 0.0816
#   30: 0.0816
#   30kg: 0.0816
#   3kg: 0.0816
#   40ft: 0.0816
#   45: 0.1632
#   50: 0.0709
#   55: 0.1632
#   5kg: 0.1419
#   60: 0.0816
#   70: 0.0816
#   9kg: 0.0816
#   ability: 0.0669
#   anushka: 0.0507
#   avni: 0.0507
#   bag: 0.1632
#   called: 0.0757
#   container: 0.1268
#   cultivars: 0.0891
#   exporters: 0.0816
#   flesh: 0.0891
#   fresh: 0.0634
#   indian: 0.0891
#   international: 0.0507
#   jute: 0.0816
#   kinds: 0.0816
#   like: 0.0709
#   load: 0.0669
#   major: 0.0757
#   mesh: 0.0816
#   mm: 0.3263
#   mt: 0.1632
#   odo: 0.0816
#   onion: 0.0816
#   onions: 0.5301
#   packaging: 0.0634
#   per: 0.1268
#   pink: 0.3565
#   red: 0.1902
#   refer: 0.0816
#   sizes: 0.0816
#   skin: 0.0757
#   sometimes: 0.0891
#   summer: 0.0998
#   suppliers: 0.0575
#   tinged: 0.0891
#   white: 0.1632
#
# document #16: Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying and exportingAgro Products. We thoroughly consider the demand and requirement ofthe client till the final destination. The company professionals are aware of the fact that demands of thecustomers keep evolving. We do have strong background in Horticultureand Harvest handling of perishables. Company takes initiatives to deliver the best quality to thecustomers. Moreover, we have established ourselves in the market forproviding the best quality all across the domestic and Internationalmarket.
#   aai: 0.0830
#   across: 0.1237
#   agro: 0.0830
#   anushka: 0.0628
#   assortment: 0.0830
#   available: 0.0786
#   avni: 0.0628
#   aware: 0.1237
#   background: 0.1237
#   best: 0.3035
#   buyers: 0.0830
#   client: 0.1237
#   come: 0.0748
#   company: 0.2211
#   consider: 0.1237
#   deliver: 0.1237
#   demand: 0.1237
#   demands: 0.1237
#   destination: 0.1237
#   domestic: 0.1237
#   established: 0.1237
#   evolving: 0.1237
#   exporter: 0.0830
#   exportingagro: 0.1237
#   fact: 0.1237
#   feel: 0.0830
#   final: 0.1237
#   follow: 0.0939
#   forproviding: 0.1237
#   handling: 0.1237
#   harvest: 0.1237
#   horticultureand: 0.1237
#   huge: 0.0830
#   initiatives: 0.1237
#   international: 0.0628
#   internationalmarket: 0.1237
#   keep: 0.1237
#   market: 0.1659
#   moreover: 0.1237
#   offer: 0.0830
#   ofthe: 0.1237
#   one: 0.0683
#   perishables: 0.1237
#   pleasure: 0.0830
#   practices: 0.1012
#   presenting: 0.0830
#   products: 0.1659
#   professionals: 0.1237
#   proud: 0.0830
#   quality: 0.2359
#   recognizing: 0.0830
#   renowned: 0.0830
#   requirement: 0.1237
#   standard: 0.0830
#   strong: 0.1237
#   suppliers: 0.0714
#   supplying: 0.1012
#   takes: 0.1659
#   thecustomers: 0.2474
#   thoroughly: 0.1237
#   till: 0.1237
#   us: 0.1659
#   wide: 0.0830
#   world: 0.0830
#
# document #17: We are one of the leading organizations engaged in delivering our customers with Fresh Onions. We manufacture this in bulk requirements for our clients. Malaysia, Singapore, Philippines, Vietnam Quality Product Details:
#   bulk: 0.2272
#   clients: 0.2544
#   customers: 0.2544
#   delivering: 0.2544
#   details: 0.1931
#   engaged: 0.2544
#   fresh: 0.1616
#   leading: 0.2544
#   malaysia: 0.2272
#   manufacture: 0.2544
#   one: 0.1403
#   onions: 0.1931
#   organizations: 0.2544
#   philippines: 0.2544
#   product: 0.2272
#   quality: 0.1616
#   requirements: 0.2544
#   singapore: 0.2272
#   vietnam: 0.2544
#
# document #18: Fresh Tomatoes from Anushka Avni International We have emerged as one of the reputed organization actively participating in exporting and suppling Red Tomatoes. Product Details: Taste enhancer Free from preservatives Pure Useful for chutney Packing : 6.5 kg, 7.00 kg Cartons.
#   00: 0.2029
#   actively: 0.2029
#   anushka: 0.1030
#   avni: 0.1030
#   cartons: 0.1540
#   chutney: 0.2029
#   details: 0.1540
#   emerged: 0.2029
#   enhancer: 0.2029
#   exporting: 0.2029
#   free: 0.2029
#   fresh: 0.1289
#   international: 0.1030
#   kg: 0.2885
#   one: 0.1119
#   organization: 0.2029
#   packing: 0.1659
#   participating: 0.2029
#   preservatives: 0.2029
#   product: 0.1812
#   pure: 0.2029
#   red: 0.1289
#   reputed: 0.2029
#   suppling: 0.2029
#   taste: 0.1540
#   tomatoes: 0.3625
#   useful: 0.2029
#
# document #19: Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market.
#   aai: 0.1865
#   agro: 0.1865
#   anushka: 0.1412
#   assortment: 0.1865
#   available: 0.1767
#   avni: 0.1412
#   buyers: 0.1865
#   come: 0.1681
#   exporter: 0.1865
#   feel: 0.1865
#   huge: 0.1865
#   international: 0.1412
#   market: 0.1865
#   offer: 0.1865
#   one: 0.1535
#   pleasure: 0.1865
#   presenting: 0.1865
#   products: 0.1865
#   proud: 0.1865
#   quality: 0.1767
#   recognizing: 0.1865
#   renowned: 0.1865
#   standard: 0.1865
#   suppliers: 0.1604
#   takes: 0.1865
#   us: 0.3730
#   wide: 0.1865
#   world: 0.1865
#
# document #20: Welcome to Anushka Avni International (AAI) Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market.
#   aai: 0.3197
#   agro: 0.1599
#   anushka: 0.2421
#   assortment: 0.1599
#   available: 0.1515
#   avni: 0.2421
#   buyers: 0.1599
#   come: 0.1441
#   exporter: 0.1599
#   feel: 0.1599
#   huge: 0.1599
#   international: 0.2421
#   market: 0.1599
#   offer: 0.1599
#   one: 0.1315
#   pleasure: 0.1599
#   presenting: 0.1599
#   products: 0.1599
#   proud: 0.1599
#   quality: 0.1515
#   recognizing: 0.1599
#   renowned: 0.1599
#   standard: 0.1599
#   suppliers: 0.1375
#   takes: 0.1599
#   us: 0.3197
#   welcome: 0.2384
#   wide: 0.1599
#   world: 0.1599
#
# document #21: Thomson Seedless These grapes are seedless, sweet-tart, and crunchy. Thomson Seedless account for the bulk of Table Grape exports from India. Berry Size: 16mm and above
#   16mm: 0.2172
#   account: 0.2172
#   berry: 0.1776
#   bulk: 0.1940
#   crunchy: 0.2172
#   exports: 0.2172
#   grape: 0.2172
#   grapes: 0.1776
#   india: 0.1940
#   seedless: 0.5329
#   size: 0.1649
#   sweet: 0.1776
#   table: 0.2172
#   tart: 0.2172
#   thomson: 0.4344
#
# document #22: Black Sharad Seedless Grapes Crisp to taste, these grapes vary in shades of black to purple. Each berry is usually medium-sized and oval-shaped. Berry Size: 18mm and above Packaging Packing Size: 4.5 kg loose in carry bags 8.2 kg loose in carry bags 5 kg carton punnets10 x 500 gms Load ability: 5 kg – 2400 cartons per container 4.5 kilo – 3400 cartons per container 8.2 kilo – 2040 cartons per container Availability: December | January | February | March | April
#   18mm: 0.1094
#   2040: 0.1094
#   2400: 0.1094
#   3400: 0.1094
#   500: 0.1094
#   ability: 0.0821
#   april: 0.1001
#   availability: 0.0930
#   bags: 0.2188
#   berry: 0.2003
#   black: 0.2188
#   carry: 0.2188
#   carton: 0.0930
#   cartons: 0.2789
#   container: 0.2335
#   crisp: 0.1225
#   december: 0.1094
#   february: 0.1001
#   gms: 0.1094
#   grapes: 0.2003
#   january: 0.1001
#   kg: 0.3484
#   kilo: 0.2188
#   load: 0.0821
#   loose: 0.2003
#   march: 0.1001
#   medium: 0.1225
#   oval: 0.1225
#   packaging: 0.0778
#   packing: 0.1001
#   per: 0.2335
#   punnets10: 0.1094
#   purple: 0.1094
#   seedless: 0.1001
#   shades: 0.1225
#   shaped: 0.1094
#   sharad: 0.1225
#   size: 0.1859
#   sized: 0.1225
#   taste: 0.0930
#   usually: 0.1225
#   vary: 0.1225
#
# document #23: Flame / Red seedless grapesFlame grapes are one of the most popular varieties along with…
#   along: 0.3767
#   flame: 0.3767
#   grapes: 0.3081
#   grapesflame: 0.3767
#   one: 0.2079
#   popular: 0.3767
#   red: 0.2394
#   seedless: 0.3081
#   varieties: 0.3767
#
# document #24: A Dictionary in Python is an unordered collection of data values, used to store data values like a map, which, unlike other Data Types that hold only a single value as an element, Dictionary holds key:value pair.
#   collection: 0.1736
#   data: 0.4652
#   dictionary: 0.3471
#   element: 0.1736
#   hold: 0.1736
#   holds: 0.1736
#   key: 0.1736
#   like: 0.1234
#   map: 0.1736
#   pair: 0.1736
#   python: 0.1736
#   single: 0.1736
#   store: 0.1736
#   types: 0.1736
#   unlike: 0.1736
#   unordered: 0.1736
#   used: 0.1234
#   value: 0.3471
#   values: 0.3471
#
# document #25: Botany originated in prehistory as herbalism with the efforts of early humans to identify – and later cultivate – edible, medicinal and poisonous plants, making it one of the oldest branches of science. Medieval physic gardens, often attached to monasteries, contained plants of medical importance. They were forerunners of the first botanical gardens attached to universities, founded from the 1540s onwards. One of the earliest was the Padua botanical garden. These gardens facilitated the academic study of plants. Efforts to catalogue and describe their collections were the beginnings of plant taxonomy, and led in 1753 to the binomial system of nomenclature of Carl Linnaeus that remains in use to this day for the naming of all biological species.
#   1540s: 0.1107
#   1753: 0.1107
#   academic: 0.1107
#   attached: 0.2213
#   beginnings: 0.1107
#   binomial: 0.1107
#   biological: 0.1107
#   botanical: 0.2213
#   botany: 0.0989
#   branches: 0.1107
#   carl: 0.1107
#   catalogue: 0.1107
#   collections: 0.1107
#   contained: 0.1107
#   cultivate: 0.1107
#   day: 0.0989
#   describe: 0.1107
#   earliest: 0.1107
#   early: 0.1107
#   edible: 0.1107
#   efforts: 0.2213
#   facilitated: 0.1107
#   first: 0.0989
#   forerunners: 0.1107
#   founded: 0.1107
#   garden: 0.1107
#   gardens: 0.3320
#   herbalism: 0.1107
#   humans: 0.0989
#   identify: 0.1107
#   importance: 0.1107
#   later: 0.1107
#   led: 0.1107
#   linnaeus: 0.1107
#   making: 0.1107
#   medical: 0.1107
#   medicinal: 0.1107
#   medieval: 0.1107
#   monasteries: 0.1107
#   naming: 0.1107
#   nomenclature: 0.1107
#   often: 0.0989
#   oldest: 0.1107
#   one: 0.1221
#   onwards: 0.1107
#   originated: 0.1107
#   padua: 0.1107
#   physic: 0.1107
#   plant: 0.0989
#   plants: 0.2966
#   poisonous: 0.1107
#   prehistory: 0.1107
#   remains: 0.1107
#   science: 0.0905
#   species: 0.1107
#   study: 0.1107
#   system: 0.1107
#   taxonomy: 0.1107
#   universities: 0.1107
#   use: 0.0989
#
# document #26: Semantic similarity is a metric defined over a set of documents or terms, where the idea of distance between items is based on the likeness of their meaning or semantic content as opposed to lexicographical similarity. These are mathematical tools used to estimate the strength of the semantic relationship between units of language, concepts or instances, through a numerical description obtained according to the comparison of information supporting their meaning or describing their nature.
#   according: 0.1439
#   based: 0.1439
#   comparison: 0.1439
#   concepts: 0.1439
#   content: 0.1439
#   defined: 0.1439
#   describing: 0.1439
#   description: 0.1439
#   distance: 0.1439
#   documents: 0.1439
#   estimate: 0.1439
#   idea: 0.1439
#   information: 0.1439
#   instances: 0.1439
#   items: 0.1439
#   language: 0.1439
#   lexicographical: 0.1439
#   likeness: 0.1439
#   mathematical: 0.1439
#   meaning: 0.2878
#   metric: 0.1439
#   nature: 0.1439
#   numerical: 0.1439
#   obtained: 0.1439
#   opposed: 0.1439
#   relationship: 0.1439
#   semantic: 0.4316
#   set: 0.1439
#   similarity: 0.2878
#   strength: 0.1439
#   supporting: 0.1439
#   terms: 0.1439
#   tools: 0.1285
#   units: 0.1439
#   used: 0.1023
#
# document #27: Botany, also called plant science(s), plant biology or phytology, is the science of plant life and a branch of biology. A botanist, plant scientist or phytologist is a scientist who specialises in this field.
#   also: 0.1261
#   biology: 0.3547
#   botanist: 0.1584
#   botany: 0.1584
#   branch: 0.1774
#   called: 0.1346
#   field: 0.1774
#   life: 0.1450
#   phytologist: 0.1774
#   phytology: 0.1774
#   plant: 0.6338
#   science: 0.2901
#   scientist: 0.3547
#   specialises: 0.1774
#
# document #28: The Ford Bronco is a model line of sport utility vehicles manufactured and marketed by Ford. ... The first SUV model developed by the company, five generations of the Bronco were sold from the 1966 to 1996 model years. A sixth generation of the model line is sold from the 2021 model year. the Ford Bronco will be available in Canada, with first deliveries beginning in spring of 2021. The Bronco will come in six versions in Canada: Base, Big Bend, Black Diamond, Outer Banks, Wildtrak and Badlands.
#   1966: 0.1011
#   1996: 0.1011
#   2021: 0.2022
#   available: 0.0642
#   badlands: 0.1011
#   banks: 0.1011
#   base: 0.1011
#   beginning: 0.1011
#   bend: 0.1011
#   big: 0.1011
#   black: 0.0903
#   bronco: 0.4043
#   canada: 0.1535
#   come: 0.0611
#   company: 0.0903
#   deliveries: 0.1011
#   developed: 0.1011
#   diamond: 0.1011
#   first: 0.1806
#   five: 0.1011
#   ford: 0.3033
#   generation: 0.1011
#   generations: 0.1011
#   line: 0.2022
#   manufactured: 0.1011
#   marketed: 0.1011
#   model: 0.5054
#   outer: 0.1011
#   six: 0.1011
#   sixth: 0.1011
#   sold: 0.2022
#   sport: 0.1011
#   spring: 0.1011
#   suv: 0.1011
#   utility: 0.1011
#   vehicles: 0.1011
#   versions: 0.1011
#   wildtrak: 0.1011
#   year: 0.1011
#   years: 0.1011
#
# document #29: Fruit dishes are those that use fruit as a primary ingredient. Condiments prepared with fruit as a primary ingredient are also included in this list.
#   also: 0.1638
#   condiments: 0.2303
#   dishes: 0.2303
#   fruit: 0.4913
#   included: 0.2303
#   ingredient: 0.4606
#   list: 0.2303
#   prepared: 0.2303
#   primary: 0.4606
#   use: 0.2057
#
# document #30: Neuro linguistic programming (NLP) is a pseudoscientific approach to communication, personal development, and psychotherapy created by Richard Bandler and John Grinder in California, United States, in the 1970s.
#   1970s: 0.2306
#   approach: 0.2306
#   bandler: 0.2306
#   california: 0.2306
#   communication: 0.2306
#   created: 0.2306
#   development: 0.2306
#   grinder: 0.2306
#   john: 0.2306
#   linguistic: 0.2306
#   neuro: 0.2306
#   nlp: 0.2306
#   personal: 0.2306
#   programming: 0.2306
#   pseudoscientific: 0.2306
#   psychotherapy: 0.2306
#   richard: 0.2306
#   states: 0.2061
#   united: 0.2306
#
# document #31: A fruit serving bowl is a round dish or container typically used to prepare and serve food. The interior of a bowl is characteristically shaped like a spherical cap, with the edges and the bottom forming a seamless curve. This makes bowls especially suited for holding liquids and loose food, as the contents of the bowl are naturally concentrated in its center by the force of gravity.
#   bottom: 0.1532
#   bowl: 0.4597
#   bowls: 0.1532
#   cap: 0.1532
#   center: 0.1532
#   characteristically: 0.1532
#   concentrated: 0.1532
#   container: 0.0974
#   contents: 0.1532
#   curve: 0.1532
#   dish: 0.1532
#   edges: 0.1532
#   especially: 0.1532
#   food: 0.2738
#   force: 0.1532
#   forming: 0.1532
#   fruit: 0.1090
#   gravity: 0.1532
#   holding: 0.1532
#   interior: 0.1532
#   like: 0.1090
#   liquids: 0.1532
#   loose: 0.1253
#   makes: 0.1532
#   naturally: 0.1532
#   prepare: 0.1532
#   round: 0.1532
#   seamless: 0.1532
#   serve: 0.1532
#   serving: 0.1532
#   shaped: 0.1369
#   spherical: 0.1532
#   suited: 0.1532
#   typically: 0.1532
#   used: 0.1090

# %%
# for each query, output the similarity scores for the top 5 documents with
# th highest score, and interpret your results

queries = ['fruits', 'vegetables', 'healthy foods in Canada']

for query in queries:
  # transforms each query into a TF-IDF vector based on the same vocabulary and weights learned from the documents
  query_vector = vectorizer.transform([query])

  # use cosine similarity between the query vector and all document vectors
  cosine_similarities = linear_kernel(query_vector, document_vectors).flatten()

  # sort the indices of the documents by their similarity scores in descending order
  top_indices = cosine_similarities.argsort()[::-1]

  print(f"query: {query}")
  for index in top_indices[:5]:
      print(f">> score: {cosine_similarities[index]:.4f} for document #{index}: {documents[index]}")
  print()
# Out:
# query: fruits
# >> score: 0.1790 for document #6: To a botanist, a fruit is an entity that develops from the fertilized ovary of a flower. This means that tomatoes, squash, pumpkins, cucumbers, peppers, eggplants, corn kernels, and bean and pea pods are all fruits; so are apples, pears, peaches, apricots, melons and mangos
# >> score: 0.0800 for document #10: Canada's Food Guide is a nutrition guide produced by Health Canada to promote Healthy behaviours and habits, and lifestyles in Canada - this is to increase the number of healthy people in Canada. In 2007, it was reported to be the second most requested Canadian government publication, behind the Income Tax Forms. The Health Canada website states: Food guides are basic education tools that are designed to help people follow a healthy diet. The Guide recommends eating a variety of healthy foods each day including plenty of vegetables and fruits, protein foods, and whole grain foods. It recommends choosing protein foods that come from plants more often. It also recommends limiting highly processed foods.
# >> score: 0.0000 for document #31: A fruit serving bowl is a round dish or container typically used to prepare and serve food. The interior of a bowl is characteristically shaped like a spherical cap, with the edges and the bottom forming a seamless curve. This makes bowls especially suited for holding liquids and loose food, as the contents of the bowl are naturally concentrated in its center by the force of gravity.
# >> score: 0.0000 for document #30: Neuro linguistic programming (NLP) is a pseudoscientific approach to communication, personal development, and psychotherapy created by Richard Bandler and John Grinder in California, United States, in the 1970s.
# >> score: 0.0000 for document #1: Fresh Pomegranate Arakta from Anushka Avni International This Pomegranate are bigger in size, sweet with soft seeds, bold red arils. It also possess glossy, attractive, dark red skin. Packaging: Net weight of box 2.5kg, 3.00kg, 3.5kg. Details: Minimum Weight 180gm, maximum weight 400gm Taste: Sweet Fruit count / carton (3.50 kg net wt.) 9 Numbers packed per carton: 350-400gms 10 Numbers packed per carton :290-320gms 12 Numbers packed per carton: 275-325gms 15 Numbers packed per carton: 225-275gms Load ability: 4400 cartons per container 20 pallets with 220 cartons per pallet Load ability: 5500 cartons per container Loading with No pallets Availability: January | February | March | April | July | August | September | October | Nov | Dec READ MORE
#
# query: vegetables
# >> score: 0.0895 for document #10: Canada's Food Guide is a nutrition guide produced by Health Canada to promote Healthy behaviours and habits, and lifestyles in Canada - this is to increase the number of healthy people in Canada. In 2007, it was reported to be the second most requested Canadian government publication, behind the Income Tax Forms. The Health Canada website states: Food guides are basic education tools that are designed to help people follow a healthy diet. The Guide recommends eating a variety of healthy foods each day including plenty of vegetables and fruits, protein foods, and whole grain foods. It recommends choosing protein foods that come from plants more often. It also recommends limiting highly processed foods.
# >> score: 0.0000 for document #31: A fruit serving bowl is a round dish or container typically used to prepare and serve food. The interior of a bowl is characteristically shaped like a spherical cap, with the edges and the bottom forming a seamless curve. This makes bowls especially suited for holding liquids and loose food, as the contents of the bowl are naturally concentrated in its center by the force of gravity.
# >> score: 0.0000 for document #30: Neuro linguistic programming (NLP) is a pseudoscientific approach to communication, personal development, and psychotherapy created by Richard Bandler and John Grinder in California, United States, in the 1970s.
# >> score: 0.0000 for document #1: Fresh Pomegranate Arakta from Anushka Avni International This Pomegranate are bigger in size, sweet with soft seeds, bold red arils. It also possess glossy, attractive, dark red skin. Packaging: Net weight of box 2.5kg, 3.00kg, 3.5kg. Details: Minimum Weight 180gm, maximum weight 400gm Taste: Sweet Fruit count / carton (3.50 kg net wt.) 9 Numbers packed per carton: 350-400gms 10 Numbers packed per carton :290-320gms 12 Numbers packed per carton: 275-325gms 15 Numbers packed per carton: 225-275gms Load ability: 4400 cartons per container 20 pallets with 220 cartons per pallet Load ability: 5500 cartons per container Loading with No pallets Availability: January | February | March | April | July | August | September | October | Nov | Dec READ MORE
# >> score: 0.0000 for document #2: About Us Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying… Read More..
#
# query: healthy foods in Canada
# >> score: 0.6315 for document #10: Canada's Food Guide is a nutrition guide produced by Health Canada to promote Healthy behaviours and habits, and lifestyles in Canada - this is to increase the number of healthy people in Canada. In 2007, it was reported to be the second most requested Canadian government publication, behind the Income Tax Forms. The Health Canada website states: Food guides are basic education tools that are designed to help people follow a healthy diet. The Guide recommends eating a variety of healthy foods each day including plenty of vegetables and fruits, protein foods, and whole grain foods. It recommends choosing protein foods that come from plants more often. It also recommends limiting highly processed foods.
# >> score: 0.3137 for document #9: In nutrition, the diet of an organism is the sum of foods it eats, which is largely determined by the availability and palatability of foods.
# >> score: 0.1072 for document #12: Canadian Industry Statistics (CIS) analyses industry data on many economic indicators in Canada
# >> score: 0.0877 for document #11: UK, Nether Land, Russia, Canada, HongKong, Malaysia, Singapore, Oman, UAE, Qatar, Bahrain, Saudi Arabia, Mauritius, Maldives, Sri Lanka, Bangladesh
# >> score: 0.0756 for document #28: The Ford Bronco is a model line of sport utility vehicles manufactured and marketed by Ford. ... The first SUV model developed by the company, five generations of the Bronco were sold from the 1966 to 1996 model years. A sixth generation of the model line is sold from the 2021 model year. the Ford Bronco will be available in Canada, with first deliveries beginning in spring of 2021. The Bronco will come in six versions in Canada: Base, Big Bend, Black Diamond, Outer Banks, Wildtrak and Badlands.

# %% [markdown]
# ## Repeat the same task after some preprocessing
#
# Use a minimum of 2 different text cleaning/standardization techniques (e.g. lemmatization, removing punctuation, etc).

# %%
# e.g. you can use a lemmatizer to reduce words down to their
# simplest 'lemma' (helpful when dealing with plurals)

from nltk import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# initialize the lemmatizer
lemmatizer = WordNetLemmatizer()

def custom_preprocessor(text):
    # tokenize text
    tokens = nltk.word_tokenize(text.lower())
    # lemmatize each token
    lemmatized_tokens = [
        lemmatizer.lemmatize(token) for token in tokens if token.isalnum() and token not in stop_words
    ]
    return " ".join(lemmatized_tokens)

# > initialize the vectorizer with the custom preprocessor
vectorizer = TfidfVectorizer(preprocessor=custom_preprocessor)

# > fit and transform the documents
document_vectors = vectorizer.fit_transform(documents)

# > print feature names (vocabulary) after preprocessing
print("Vocabulary: ", vectorizer.get_feature_names_out())
# Out:
# Vocabulary:  ['10' '10kg' '12' '15' '1540s' '15kg' '16mm' '1753' '17kg' '180gm' '18kg'
#  '18mm' '1966' '1970s' '1996' '20' '2007' '2021' '2040' '20ft' '20kg'
#  '220' '2400' '25kg' '28' '30kg' '3400' '3kg' '400gm' '40ft' '4400' '50'
#  '500' '5500' '5kg' '60' '9kg' 'aai' 'ability' 'absorption' 'academic'
#  'acclaimed' 'according' 'account' 'across' 'actively' 'agro' 'along'
#  'also' 'analysis' 'animal' 'anushka' 'appearance' 'apple' 'approach'
#  'apricot' 'april' 'arabia' 'arakta' 'aril' 'assimilation' 'assortment'
#  'attached' 'attractive' 'august' 'availability' 'available' 'avni'
#  'aware' 'background' 'badlands' 'bag' 'bahrain' 'bandler' 'bangladesh'
#  'bank' 'base' 'based' 'basic' 'bean' 'beginning' 'behaviour' 'behind'
#  'bend' 'benefit' 'berry' 'best' 'bhagwa' 'big' 'bigger' 'binomial'
#  'biochemical' 'biological' 'biology' 'biosynthesis' 'black' 'bold'
#  'botanical' 'botanist' 'botany' 'bottom' 'bowl' 'box' 'branch' 'bronco'
#  'bulk' 'buyer' 'california' 'called' 'canada' 'canadian' 'cap'
#  'carbohydrate' 'carl' 'carry' 'carton' 'catabolism' 'catalogue' 'center'
#  'characteristically' 'cherry' 'choosing' 'chutney' 'ci' 'class' 'client'
#  'collection' 'color' 'come' 'communication' 'company' 'comparison'
#  'concentrated' 'concept' 'condiment' 'consider' 'contained' 'container'
#  'content' 'corn' 'count' 'created' 'crisp' 'crunchy' 'cucumber' 'cuisine'
#  'cultivar' 'cultivate' 'curve' 'customer' 'dark' 'data' 'day' 'dec'
#  'december' 'deep' 'defined' 'delicious' 'deliver' 'delivering' 'delivery'
#  'demand' 'describe' 'describing' 'description' 'designed' 'destination'
#  'detail' 'determined' 'developed' 'development' 'develops' 'diamond'
#  'dictionary' 'diet' 'dietary' 'different' 'dish' 'distance' 'document'
#  'domestic' 'earliest' 'early' 'eating' 'eats' 'economic' 'edge' 'edible'
#  'education' 'effort' 'eggplant' 'either' 'element' 'emerged' 'engaged'
#  'enhancer' 'enhances' 'entity' 'especially' 'established' 'estimate'
#  'evolving' 'excretion' 'export' 'exporter' 'exporting' 'exportingagro'
#  'extremely' 'facilitated' 'fact' 'fat' 'february' 'feel' 'fertilized'
#  'fiber' 'field' 'final' 'first' 'five' 'flame' 'flesh' 'flower' 'follow'
#  'food' 'force' 'ford' 'forerunner' 'form' 'forming' 'forproviding'
#  'founded' 'free' 'fresh' 'fruit' 'garden' 'generation' 'glossy' 'gm'
#  'government' 'grain' 'gram' 'grape' 'grapesflame' 'gravity' 'grinder'
#  'grouped' 'grow' 'guide' 'habit' 'handling' 'harvest' 'health' 'healthy'
#  'help' 'herbalism' 'highly' 'hold' 'holding' 'hongkong' 'horticultureand'
#  'huge' 'human' 'idea' 'identify' 'importance' 'included' 'includes'
#  'including' 'income' 'increase' 'india' 'indian' 'indicator' 'industry'
#  'information' 'ingestion' 'ingredient' 'initiative' 'instance' 'intake'
#  'interior' 'international' 'internationalmarket' 'item' 'january' 'john'
#  'july' 'jute' 'keep' 'kernel' 'key' 'kg' 'kilo' 'kind' 'known' 'land'
#  'language' 'lanka' 'largely' 'later' 'leading' 'led' 'lexicographical'
#  'life' 'lifestyle' 'like' 'likeness' 'limiting' 'line' 'linguistic'
#  'linnaeus' 'liquid' 'list' 'load' 'loading' 'loose' 'macronutrients'
#  'major' 'make' 'making' 'malaysia' 'maldives' 'mango' 'manufacture'
#  'manufactured' 'many' 'map' 'march' 'market' 'marketed' 'mathematical'
#  'mauritius' 'maximum' 'mean' 'meaning' 'medical' 'medicinal' 'medieval'
#  'melon' 'mesh' 'metric' 'microgram' 'micronutrient' 'milligram' 'mineral'
#  'minimum' 'mm' 'model' 'monastery' 'moreover' 'mt' 'naming' 'naturally'
#  'nature' 'needed' 'net' 'nether' 'neuro' 'nlp' 'nomenclature' 'nov'
#  'number' 'numerical' 'nutrient' 'nutrition' 'nutritional' 'obtained'
#  'october' 'odo' 'offer' 'often' 'ofthe' 'oldest' 'oman' 'one' 'onion'
#  'onwards' 'opposed' 'organism' 'organization' 'originated' 'outer'
#  'ovary' 'packaging' 'packed' 'packing' 'padua' 'pair' 'palatability'
#  'pallet' 'participating' 'pea' 'peach' 'pear' 'people' 'pepper' 'per'
#  'perishable' 'personal' 'philippine' 'physic' 'physiological'
#  'phytologist' 'phytology' 'pink' 'plant' 'pleasing' 'pleasure' 'plenty'
#  'pod' 'poisonous' 'pomegranate' 'popular' 'possess' 'practice'
#  'prehistory' 'premium' 'prepare' 'prepared' 'presenting' 'preservative'
#  'primary' 'process' 'processed' 'produced' 'product' 'professional'
#  'programming' 'promote' 'promoting' 'protein' 'proud' 'pseudoscientific'
#  'psychotherapy' 'publication' 'pumpkin' 'punnets10' 'pure' 'purple'
#  'purplish' 'python' 'qatar' 'quality' 'quantity' 'read' 'recognizing'
#  'recommends' 'red' 'refer' 'relationship' 'relevant' 'remains' 'renowned'
#  'reported' 'reproduce' 'reputed' 'requested' 'requirement' 'richard'
#  'round' 'rugged' 'russia' 'saudi' 'science' 'scientist' 'seamless'
#  'second' 'seed' 'seedless' 'semantic' 'september' 'serve' 'serving' 'set'
#  'seven' 'shade' 'shaped' 'sharad' 'shelf' 'similarity' 'singapore'
#  'single' 'six' 'sixth' 'size' 'skin' 'soft' 'sold' 'sometimes'
#  'specialises' 'specie' 'spherical' 'sport' 'spring' 'squash' 'sri'
#  'standard' 'state' 'statistic' 'store' 'strength' 'strong' 'study'
#  'substance' 'suited' 'sum' 'summer' 'supplier' 'suppling' 'supplying'
#  'support' 'supporting' 'survive' 'suv' 'sweet' 'system' 'table' 'take'
#  'taste' 'tax' 'taxonomy' 'term' 'thecustomers' 'thomson' 'thoroughly'
#  'till' 'tinged' 'tomato' 'tool' 'type' 'typically' 'uae' 'uk' 'unit'
#  'united' 'university' 'unlike' 'unordered' 'us' 'use' 'used' 'useful'
#  'usually' 'utility' 'value' 'variety' 'vary' 'vegetable' 'vehicle'
#  'version' 'vietnam' 'vitamin' 'water' 'website' 'weight' 'welcome'
#  'whilst' 'white' 'whole' 'wide' 'widely' 'wildtrak' 'world' 'wt' 'year']

# %%
# > show preprocessed documents
print("Preprocessed Documents:")
for i, doc in enumerate(documents):
    print(f"doc #{i} - original: {doc}")
    print(f"doc #{i} - processed: {custom_preprocessor(doc)}")
    print()
# Out:
# Preprocessed Documents:
# doc #0 - original: Fresh Pomegranate from Anushka Avni International Bhagwa is a premium Pomegranate variety from India. The Deep Red arils & the pleasing Red but rugged skin enhances the appearance whilst promoting shelf life of the fruit. Bhagwa is widely known for its soft seed, Dark red color and extremely delicious. Packaging: Net weight of box 2.5kg, 3.00kg, 3.5kg. Details: Minimum Weight 180gm, maximum weight 400gm Color of arils: Dark Cherry red. Taste: Sweet Fruit count / carton (3.50 kg net wt.) 9 Numbers packed per carton: 350-400gms
# doc #0 - processed: fresh pomegranate anushka avni international bhagwa premium pomegranate variety india deep red aril pleasing red rugged skin enhances appearance whilst promoting shelf life fruit bhagwa widely known soft seed dark red color extremely delicious packaging net weight box detail minimum weight 180gm maximum weight 400gm color aril dark cherry red taste sweet fruit count carton kg net wt 9 number packed per carton
#
# doc #1 - original: Fresh Pomegranate Arakta from Anushka Avni International This Pomegranate are bigger in size, sweet with soft seeds, bold red arils. It also possess glossy, attractive, dark red skin. Packaging: Net weight of box 2.5kg, 3.00kg, 3.5kg. Details: Minimum Weight 180gm, maximum weight 400gm Taste: Sweet Fruit count / carton (3.50 kg net wt.) 9 Numbers packed per carton: 350-400gms 10 Numbers packed per carton :290-320gms 12 Numbers packed per carton: 275-325gms 15 Numbers packed per carton: 225-275gms Load ability: 4400 cartons per container 20 pallets with 220 cartons per pallet Load ability: 5500 cartons per container Loading with No pallets Availability: January | February | March | April | July | August | September | October | Nov | Dec READ MORE
# doc #1 - processed: fresh pomegranate arakta anushka avni international pomegranate bigger size sweet soft seed bold red aril also possess glossy attractive dark red skin packaging net weight box detail minimum weight 180gm maximum weight 400gm taste sweet fruit count carton kg net wt 9 number packed per carton 10 number packed per carton 12 number packed per carton 15 number packed per carton load ability 4400 carton per container 20 pallet 220 carton per pallet load ability 5500 carton per container loading pallet availability january february march april july august september october nov dec read
#
# doc #2 - original: About Us Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying… Read More..
# doc #2 - processed: u anushka avni international aai take pleasure presenting one renowned supplier exporter huge assortment agro product available u feel proud buyer come u recognizing standard quality offer world wide market follow best practice read
#
# doc #3 - original: About Us Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying… Read More..
# doc #3 - processed: u anushka avni international aai take pleasure presenting one renowned supplier exporter huge assortment agro product available u feel proud buyer come u recognizing standard quality offer world wide market follow best practice read
#
# doc #4 - original: White Onions from Anushka Avni International Fresh White Onion, which is widely acclaimed for its health benefits and is used for different cuisines. We are a major exporters and suppliers of all kinds of fresh onions like red onions, pink onions and white onions. Sizes: 30-45 mm 45-55 mm 50 mm and above 55-70 mm 60 and above Packaging: 2.5kg, 3kg, 5kg, 9kg, 10kg, 15kg, 17kg, 18kg, 20kg, 25kg, 30kg Red Mesh Bag or Jute Bag Load ability: 12.5 MT per 20ft container ODO 28 MT per 40ft Refer container.
# doc #4 - processed: white onion anushka avni international fresh white onion widely acclaimed health benefit used different cuisine major exporter supplier kind fresh onion like red onion pink onion white onion size mm mm 50 mm mm 60 packaging 3kg 5kg 9kg 10kg 15kg 17kg 18kg 20kg 25kg 30kg red mesh bag jute bag load ability mt per 20ft container odo 28 mt per 40ft refer container
#
# doc #5 - original: Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market.
# doc #5 - processed: anushka avni international aai take pleasure presenting one renowned supplier exporter huge assortment agro product available u feel proud buyer come u recognizing standard quality offer world wide market
#
# doc #6 - original: To a botanist, a fruit is an entity that develops from the fertilized ovary of a flower. This means that tomatoes, squash, pumpkins, cucumbers, peppers, eggplants, corn kernels, and bean and pea pods are all fruits; so are apples, pears, peaches, apricots, melons and mangos
# doc #6 - processed: botanist fruit entity develops fertilized ovary flower mean tomato squash pumpkin cucumber pepper eggplant corn kernel bean pea pod fruit apple pear peach apricot melon mango
#
# doc #7 - original: Nutrition is the biochemical and physiological process by which an organism uses intake to support its life. It includes ingestion, absorption, assimilation, biosynthesis, catabolism and excretion. The science that studies the physiological process of nutrition is called nutritional science (also nutrition science).
# doc #7 - processed: nutrition biochemical physiological process organism us intake support life includes ingestion absorption assimilation biosynthesis catabolism excretion science study physiological process nutrition called nutritional science also nutrition science
#
# doc #8 - original: Nutrients are substances used by an organism to survive, grow, and reproduce. The seven major classes of relevant nutrients for animals (including humans) are carbohydrates, dietary fiber, fats, proteins, minerals, vitamins, and water. Nutrients can be grouped as either macronutrients (carbohydrates, dietary fiber, fats, proteins, and water needed in gram quantities) or micronutrients (vitamins and minerals needed in milligram or microgram quantities).
# doc #8 - processed: nutrient substance used organism survive grow reproduce seven major class relevant nutrient animal including human carbohydrate dietary fiber fat protein mineral vitamin water nutrient grouped either macronutrients carbohydrate dietary fiber fat protein water needed gram quantity micronutrient vitamin mineral needed milligram microgram quantity
#
# doc #9 - original: In nutrition, the diet of an organism is the sum of foods it eats, which is largely determined by the availability and palatability of foods.
# doc #9 - processed: nutrition diet organism sum food eats largely determined availability palatability food
#
# doc #10 - original: Canada's Food Guide is a nutrition guide produced by Health Canada to promote Healthy behaviours and habits, and lifestyles in Canada - this is to increase the number of healthy people in Canada. In 2007, it was reported to be the second most requested Canadian government publication, behind the Income Tax Forms. The Health Canada website states: Food guides are basic education tools that are designed to help people follow a healthy diet. The Guide recommends eating a variety of healthy foods each day including plenty of vegetables and fruits, protein foods, and whole grain foods. It recommends choosing protein foods that come from plants more often. It also recommends limiting highly processed foods.
# doc #10 - processed: canada food guide nutrition guide produced health canada promote healthy behaviour habit lifestyle canada increase number healthy people canada 2007 reported second requested canadian government publication behind income tax form health canada website state food guide basic education tool designed help people follow healthy diet guide recommends eating variety healthy food day including plenty vegetable fruit protein food whole grain food recommends choosing protein food come plant often also recommends limiting highly processed food
#
# doc #11 - original: UK, Nether Land, Russia, Canada, HongKong, Malaysia, Singapore, Oman, UAE, Qatar, Bahrain, Saudi Arabia, Mauritius, Maldives, Sri Lanka, Bangladesh
# doc #11 - processed: uk nether land russia canada hongkong malaysia singapore oman uae qatar bahrain saudi arabia mauritius maldives sri lanka bangladesh
#
# doc #12 - original: Canadian Industry Statistics (CIS) analyses industry data on many economic indicators in Canada
# doc #12 - processed: canadian industry statistic ci analysis industry data many economic indicator canada
#
# doc #13 - original: Red Onions from Anushka Avni International Red onions, sometimes called purple onions, are cultivars of the onion with purplish red skin and white flesh tinged with red. We are a major Indian exporters and suppliers of all kinds of fresh onions like red onions and white onions. Sizes: 30-45 mm 45-55 mm 50 mm and above 55-70 mm 60 and above Packaging: 2.5kg, 3kg, 5kg, 9kg, 10kg, 15kg, 17kg, 18kg, 20kg, 25kg, 30kg Red Mesh Bag or Jute Bag Load ability: 12.5 MT per 20ft container ODO 28 MT per 40ft Refer container.
# doc #13 - processed: red onion anushka avni international red onion sometimes called purple onion cultivar onion purplish red skin white flesh tinged red major indian exporter supplier kind fresh onion like red onion white onion size mm mm 50 mm mm 60 packaging 3kg 5kg 9kg 10kg 15kg 17kg 18kg 20kg 25kg 30kg red mesh bag jute bag load ability mt per 20ft container odo 28 mt per 40ft refer container
#
# doc #14 - original: Berry Size: 18mm and above Packaging Packing Size: 4.5 kg loose in carry bags 8.2 kg loose in carry bags 5 kg carton punnets10 x 500 gms Load ability: 5 kg – 2400 cartons per container 4.5 kilo – 3400 cartons per container 8.2 kilo – 2040 cartons per container Availability: December | January | February | March | April
# doc #14 - processed: berry size 18mm packaging packing size kg loose carry bag kg loose carry bag 5 kg carton punnets10 x 500 gm load ability 5 kg 2400 carton per container kilo 3400 carton per container kilo 2040 carton per container availability december january february march april
#
# doc #15 - original: Pink Onions from Anushka Avni International Pink onions, sometimes called summer onions, are cultivars of the onion with pink skin and white flesh tinged with red. We are a major Indian exporters and suppliers of all kinds of fresh onions like red onions, pink onions and white onions. Sizes: 30-45 mm 45-55 mm 50 mm and above 55-70 mm 60 and above Packaging: 2.5kg, 3kg, 5kg, 9kg, 10kg, 15kg, 17kg, 18kg, 20kg, 25kg, 30kg Red Mesh Bag or Jute Bag Load ability: 12.5 MT per 20ft container ODO 28 MT per 40ft Refer container.
# doc #15 - processed: pink onion anushka avni international pink onion sometimes called summer onion cultivar onion pink skin white flesh tinged red major indian exporter supplier kind fresh onion like red onion pink onion white onion size mm mm 50 mm mm 60 packaging 3kg 5kg 9kg 10kg 15kg 17kg 18kg 20kg 25kg 30kg red mesh bag jute bag load ability mt per 20ft container odo 28 mt per 40ft refer container
#
# doc #16 - original: Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market. We follow the best practices while supplying and exportingAgro Products. We thoroughly consider the demand and requirement ofthe client till the final destination. The company professionals are aware of the fact that demands of thecustomers keep evolving. We do have strong background in Horticultureand Harvest handling of perishables. Company takes initiatives to deliver the best quality to thecustomers. Moreover, we have established ourselves in the market forproviding the best quality all across the domestic and Internationalmarket.
# doc #16 - processed: anushka avni international aai take pleasure presenting one renowned supplier exporter huge assortment agro product available u feel proud buyer come u recognizing standard quality offer world wide market follow best practice supplying exportingagro product thoroughly consider demand requirement ofthe client till final destination company professional aware fact demand thecustomers keep evolving strong background horticultureand harvest handling perishable company take initiative deliver best quality thecustomers moreover established market forproviding best quality across domestic internationalmarket
#
# doc #17 - original: We are one of the leading organizations engaged in delivering our customers with Fresh Onions. We manufacture this in bulk requirements for our clients. Malaysia, Singapore, Philippines, Vietnam Quality Product Details:
# doc #17 - processed: one leading organization engaged delivering customer fresh onion manufacture bulk requirement client malaysia singapore philippine vietnam quality product detail
#
# doc #18 - original: Fresh Tomatoes from Anushka Avni International We have emerged as one of the reputed organization actively participating in exporting and suppling Red Tomatoes. Product Details: Taste enhancer Free from preservatives Pure Useful for chutney Packing : 6.5 kg, 7.00 kg Cartons.
# doc #18 - processed: fresh tomato anushka avni international emerged one reputed organization actively participating exporting suppling red tomato product detail taste enhancer free preservative pure useful chutney packing kg kg carton
#
# doc #19 - original: Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market.
# doc #19 - processed: anushka avni international aai take pleasure presenting one renowned supplier exporter huge assortment agro product available u feel proud buyer come u recognizing standard quality offer world wide market
#
# doc #20 - original: Welcome to Anushka Avni International (AAI) Anushka Avni International (AAI) takes pleasure in presenting itself as one of the renowned Suppliers and Exporter. We have huge assortment of agro products available with us. We feel proud when buyers come to us recognizing the standard quality which we offer in the world wide market.
# doc #20 - processed: welcome anushka avni international aai anushka avni international aai take pleasure presenting one renowned supplier exporter huge assortment agro product available u feel proud buyer come u recognizing standard quality offer world wide market
#
# doc #21 - original: Thomson Seedless These grapes are seedless, sweet-tart, and crunchy. Thomson Seedless account for the bulk of Table Grape exports from India. Berry Size: 16mm and above
# doc #21 - processed: thomson seedless grape seedless crunchy thomson seedless account bulk table grape export india berry size 16mm
#
# doc #22 - original: Black Sharad Seedless Grapes Crisp to taste, these grapes vary in shades of black to purple. Each berry is usually medium-sized and oval-shaped. Berry Size: 18mm and above Packaging Packing Size: 4.5 kg loose in carry bags 8.2 kg loose in carry bags 5 kg carton punnets10 x 500 gms Load ability: 5 kg – 2400 cartons per container 4.5 kilo – 3400 cartons per container 8.2 kilo – 2040 cartons per container Availability: December | January | February | March | April
# doc #22 - processed: black sharad seedless grape crisp taste grape vary shade black purple berry usually berry size 18mm packaging packing size kg loose carry bag kg loose carry bag 5 kg carton punnets10 x 500 gm load ability 5 kg 2400 carton per container kilo 3400 carton per container kilo 2040 carton per container availability december january february march april
#
# doc #23 - original: Flame / Red seedless grapesFlame grapes are one of the most popular varieties along with…
# doc #23 - processed: flame red seedless grapesflame grape one popular variety along
#
# doc #24 - original: A Dictionary in Python is an unordered collection of data values, used to store data values like a map, which, unlike other Data Types that hold only a single value as an element, Dictionary holds key:value pair.
# doc #24 - processed: dictionary python unordered collection data value used store data value like map unlike data type hold single value element dictionary hold key value pair
#
# doc #25 - original: Botany originated in prehistory as herbalism with the efforts of early humans to identify – and later cultivate – edible, medicinal and poisonous plants, making it one of the oldest branches of science. Medieval physic gardens, often attached to monasteries, contained plants of medical importance. They were forerunners of the first botanical gardens attached to universities, founded from the 1540s onwards. One of the earliest was the Padua botanical garden. These gardens facilitated the academic study of plants. Efforts to catalogue and describe their collections were the beginnings of plant taxonomy, and led in 1753 to the binomial system of nomenclature of Carl Linnaeus that remains in use to this day for the naming of all biological species.
# doc #25 - processed: botany originated prehistory herbalism effort early human identify later cultivate edible medicinal poisonous plant making one oldest branch science medieval physic garden often attached monastery contained plant medical importance forerunner first botanical garden attached university founded 1540s onwards one earliest padua botanical garden garden facilitated academic study plant effort catalogue describe collection beginning plant taxonomy led 1753 binomial system nomenclature carl linnaeus remains use day naming biological specie
#
# doc #26 - original: Semantic similarity is a metric defined over a set of documents or terms, where the idea of distance between items is based on the likeness of their meaning or semantic content as opposed to lexicographical similarity. These are mathematical tools used to estimate the strength of the semantic relationship between units of language, concepts or instances, through a numerical description obtained according to the comparison of information supporting their meaning or describing their nature.
# doc #26 - processed: semantic similarity metric defined set document term idea distance item based likeness meaning semantic content opposed lexicographical similarity mathematical tool used estimate strength semantic relationship unit language concept instance numerical description obtained according comparison information supporting meaning describing nature
#
# doc #27 - original: Botany, also called plant science(s), plant biology or phytology, is the science of plant life and a branch of biology. A botanist, plant scientist or phytologist is a scientist who specialises in this field.
# doc #27 - processed: botany also called plant science plant biology phytology science plant life branch biology botanist plant scientist phytologist scientist specialises field
#
# doc #28 - original: The Ford Bronco is a model line of sport utility vehicles manufactured and marketed by Ford. ... The first SUV model developed by the company, five generations of the Bronco were sold from the 1966 to 1996 model years. A sixth generation of the model line is sold from the 2021 model year. the Ford Bronco will be available in Canada, with first deliveries beginning in spring of 2021. The Bronco will come in six versions in Canada: Base, Big Bend, Black Diamond, Outer Banks, Wildtrak and Badlands.
# doc #28 - processed: ford bronco model line sport utility vehicle manufactured marketed ford first suv model developed company five generation bronco sold 1966 1996 model year sixth generation model line sold 2021 model year ford bronco available canada first delivery beginning spring bronco come six version canada base big bend black diamond outer bank wildtrak badlands
#
# doc #29 - original: Fruit dishes are those that use fruit as a primary ingredient. Condiments prepared with fruit as a primary ingredient are also included in this list.
# doc #29 - processed: fruit dish use fruit primary ingredient condiment prepared fruit primary ingredient also included list
#
# doc #30 - original: Neuro linguistic programming (NLP) is a pseudoscientific approach to communication, personal development, and psychotherapy created by Richard Bandler and John Grinder in California, United States, in the 1970s.
# doc #30 - processed: neuro linguistic programming nlp pseudoscientific approach communication personal development psychotherapy created richard bandler john grinder california united state 1970s
#
# doc #31 - original: A fruit serving bowl is a round dish or container typically used to prepare and serve food. The interior of a bowl is characteristically shaped like a spherical cap, with the edges and the bottom forming a seamless curve. This makes bowls especially suited for holding liquids and loose food, as the contents of the bowl are naturally concentrated in its center by the force of gravity.
# doc #31 - processed: fruit serving bowl round dish container typically used prepare serve food interior bowl characteristically shaped like spherical cap edge bottom forming seamless curve make bowl especially suited holding liquid loose food content bowl naturally concentrated center force gravity

# %% [markdown]
# What impact did the text cleaning / preprocessing have on your results?

# %%
# your response here

# %% [markdown]
# # Experiment 2: Semantic matching using GloVe embeddings
# ***

# %%
# if you decide to use the gensim library and the sample codes below,
# you would need gensim version >=4.0.1 to be installed
# !pip install  gensim==4.0.1
import gensim
print(gensim.__version__)

# %%
import logging
import json
import logging
from re import sub
from multiprocessing import cpu_count

import numpy as np

import gensim.downloader as api
from gensim.utils import simple_preprocess
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
from gensim.similarities import WordEmbeddingSimilarityIndex
from gensim.similarities import SparseTermSimilarityMatrix
from gensim.similarities import SoftCosineSimilarity

# %%
# optional, but it helps
import logging

# Initialize logging.
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.WARNING)

# %%
import nltk

# Import and download stopwords from NLTK.
nltk.download('stopwords')  # Download stopwords list.
stopwords = set(nltk.corpus.stopwords.words("english"))

# %%
def preprocess(doc):
    # Tokenize, clean up input document string
    doc = sub(r'<img[^<>]+(>|$)', " image_token ", doc)
    # you may decide to add additional steps here
    return [token for token in simple_preprocess(doc, min_len=0, max_len=float("inf")) if token not in stopwords]

# %%
# Load test data
with open('sample_repository.json') as in_file:
    repo_data = json.load(in_file)

titles = [item[0] for item in repo_data['data']]
documents = [item[1] for item in repo_data['data']]

# %%
query_s = 'Your queries here'

# Preprocess the documents, including the query string
corpus = [preprocess(document) for document in documents]
query = preprocess(query_s)

# %%
# Download and load the GloVe word vector embeddings
if 'glove' not in locals():  # only load if not already in memory
    glove = api.load("glove-wiki-gigaword-50")

similarity_index = WordEmbeddingSimilarityIndex(glove)

# %%
# Build the term dictionary, TF-idf model
# Keep in mind that the search query must be in the dictionary as well, in case the terms do not overlap with the documents
dictionary = Dictionary(corpus+[query])
tfidf = TfidfModel(dictionary=dictionary)

# Create the term similarity matrix.
# The nonzero_limit enforces sparsity by limiting the number of non-zero terms in each column.
# In my case, I got best results by removing the default value of 100
similarity_matrix = SparseTermSimilarityMatrix(similarity_index, dictionary, tfidf)  # , nonzero_limit=None)

# %%
# Compute similarity measure between the query and the documents.
query_tf = tfidf[dictionary.doc2bow(query)]

index = SoftCosineSimilarity(
            tfidf[[dictionary.doc2bow(document) for document in corpus]],
            similarity_matrix)

doc_similarity_scores = index[query_tf]

# %%
# for each query, output the similarity scores for the top 5 documents with
# th highest score, and interpret your results

# %% [markdown]
# # Experiment 3: BERT Model
# ***
# Use a BERT model obtain sentence embeddings and calculate the similarity between queries and documents.
#
# > Hint: see the Module 07 jupyter notebook for examples of how to work with BERT.

# %%
# for each query, output the similarity scores for the top 5 documents with
# th highest score, and interpret your results

# %% [markdown]
#  # Technique Comparison
#  ***
#
# Compare all three techniques and interpret your findings. Do your best to explain the differences you observe in terms of concepts learned in class (not just the what, but also the how and why one technique produces different results from another).
